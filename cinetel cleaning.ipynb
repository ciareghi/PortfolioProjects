# %% [markdown]
# # Cinetel Data Cleaning
#
# Cinetel data scraped daily from their online boxoffice at this [link](https://www.cinetel.it/pages/boxoffice.php?edperiodo=aWVyaQ==).

# %% [markdown]
# ## Reading In Files

# %%
import pandas as pd

# %%
df1 = pd.read_csv(r"E:\Coding\projects\cinetel_.csv")

# %% [markdown]
# ---

# %% [markdown]
# ## Cleaning the df

# %%
df1 = df1.drop_duplicates()

# %%
df1 = df1.drop(columns= ['Incasso al 16/11/2023', 'Presenze al 16/11/2023'])

# %%
df1 = df1.rename(columns = {'Pos.':'daily_rank', 'Titolo' : 'title', 'Prima Progr.' : 'first_screening_date', 'Nazione' : 'nation', 'Distribuzione' : 'distribution', 'Incasso' : 'daily_takings', 'Presenze' : 'daily_attendance',  '2023-11-17 15:31:50.351708' : 'date_pulled'})

# %%
df1 = df1[df1['daily_rank'].str.contains('Pos.')==False]

# %%
df1['title'] = df1['title'].apply(lambda x: x.title())
df1['distribution'] = df1['distribution'].apply(lambda x: x.title())

# %%
df1['first_screening_date'] = df1['first_screening_date'].str[12:]

# %%
df1['date_pulled'] = pd.to_datetime(df1['date_pulled'])
df1['date_pulled'] = pd.to_datetime(df1['date_pulled']).dt.date

#df1['date_pulled'] = df1['date_pulled'].str[:10]
#df1['date_pulled'] = df1['date_pulled'].str.replace('[^a-zA-Z0-9]', '', regex = True)
#df1['date_pulled'] = df1['date_pulled'].apply(lambda x: str(x))
#df1['date_pulled'] = df1['date_pulled'].apply(lambda x: x[0:2] + '/' + x[2:4] + '/' + x[4:8])

# %%
df1['first_screening_date'] = pd.to_datetime(df1['first_screening_date'], format='%d/%m/%Y')
df1['first_screening_date'] = pd.to_datetime(df1['first_screening_date']).dt.date

# %%
df1['date'] = 'placeholder'

# %%
df1
# Out:
#    daily_rank                                              title  \
# 0           1                                 C'E' Ancora Domani
# 1           2  Hunger Games - La Ballata Dell'Usignolo E Del ...
# 2           3                                        The Marvels
# 3           4                                       Thanksgiving
# 4           5                                        The Old Oak
# 5           6                                         Comandante
# 6           7    Trolls 3 - Tutti Insieme (Trolls Band Together)
# 7           8                            Five Nights At Freddy'S
# 8           9                         Killers Of The Flower Moon
# 9          10       Dream Scenario - Hai Mai Sognato Quest'Uomo?
# 11          1                                 C'E' Ancora Domani
# 12          2  Hunger Games - La Ballata Dell'Usignolo E Del ...
# 13          3                                        The Marvels
# 14          4                                       Thanksgiving
# 15          5                                         Comandante
# 16          6                                        The Old Oak
# 17          7    Trolls 3 - Tutti Insieme (Trolls Band Together)
# 18          8                            Five Nights At Freddy'S
# 19          9       Dream Scenario - Hai Mai Sognato Quest'Uomo?
# 20         10                         Killers Of The Flower Moon
# 22          1                                 C'E' Ancora Domani
# 23          2  Hunger Games - La Ballata Dell'Usignolo E Del ...
# 24          3                                        The Marvels
# 25          4    Trolls 3 - Tutti Insieme (Trolls Band Together)
# 26          5                                         Comandante
# 27          6                                       Thanksgiving
# 28          7                                        The Old Oak
# 29          8                            Five Nights At Freddy'S
# 30          9       Dream Scenario - Hai Mai Sognato Quest'Uomo?
# 31         10                         Killers Of The Flower Moon
# 33          1                                 C'E' Ancora Domani
# 34          2  Hunger Games - La Ballata Dell'Usignolo E Del ...
# 35          3    Trolls 3 - Tutti Insieme (Trolls Band Together)
# 36          4                                        The Marvels
# 37          5                                        The Old Oak
# 38          6                                         Comandante
# 39          7                                       Thanksgiving
# 40          8                            Five Nights At Freddy'S
# 41          9       Dream Scenario - Hai Mai Sognato Quest'Uomo?
# 42         10     Me Contro Te Il Film – Vacanze In Transilvania
#
#    first_screening_date nation               distribution daily_takings  \
# 0            2023-10-26    ITA        Vision Distribution     449991.06
# 1            2023-11-15    USA         Medusa Film S.P.A.     238466.31
# 2            2023-11-08    USA  Walt Disney S.M.P. Italia      60914.35
# 3            2023-11-16    USA      Eagle Pictures S.P.A.      41232.57
# 4            2023-11-16    FRA         Lucky Red Distrib.      36605.89
# 5            2023-10-31    ITA            01 Distribution      33606.07
# 6            2023-11-09    USA           Universal S.R.L.      20024.88
# 7            2023-11-02    USA           Universal S.R.L.      18484.63
# 8            2023-10-19    USA            01 Distribution      13874.92
# 9            2023-11-16    USA   I Wonder Pictures S.R.L.      13246.96
# 11           2023-10-26    ITA        Vision Distribution     716115.23
# 12           2023-11-15    USA         Medusa Film S.P.A.     407469.68
# 13           2023-11-08    USA  Walt Disney S.M.P. Italia     109079.49
# 14           2023-11-16    USA      Eagle Pictures S.P.A.      68469.31
# 15           2023-10-31    ITA            01 Distribution      54556.27
# 16           2023-11-16    FRA         Lucky Red Distrib.      51805.05
# 17           2023-11-09    USA           Universal S.R.L.      46814.69
# 18           2023-11-02    USA           Universal S.R.L.      45049.66
# 19           2023-11-16    USA   I Wonder Pictures S.R.L.      19793.89
# 20           2023-10-19    USA            01 Distribution      18681.33
# 22           2023-10-26    ITA        Vision Distribution    1347271.44
# 23           2023-11-15    USA         Medusa Film S.P.A.     778581.54
# 24           2023-11-08    USA  Walt Disney S.M.P. Italia     255545.91
# 25           2023-11-09    USA           Universal S.R.L.     192060.18
# 26           2023-10-31    ITA            01 Distribution     150882.31
# 27           2023-11-16    USA      Eagle Pictures S.P.A.     149022.72
# 28           2023-11-16    FRA         Lucky Red Distrib.     129453.32
# 29           2023-11-02    USA           Universal S.R.L.     128149.19
# 30           2023-11-16    USA   I Wonder Pictures S.R.L.      45799.87
# 31           2023-10-19    USA            01 Distribution      39234.41
# 33           2023-10-26    ITA        Vision Distribution    1544231.00
# 34           2023-11-15    USA         Medusa Film S.P.A.     619325.51
# 35           2023-11-09    USA           Universal S.R.L.     250674.35
# 36           2023-11-08    USA  Walt Disney S.M.P. Italia     210299.79
# 37           2023-11-16    FRA         Lucky Red Distrib.     127053.64
# 38           2023-10-31    ITA            01 Distribution     126824.19
# 39           2023-11-16    USA      Eagle Pictures S.P.A.      95936.97
# 40           2023-11-02    USA           Universal S.R.L.      80244.52
# 41           2023-11-16    USA   I Wonder Pictures S.R.L.      44300.70
# 42           2023-10-19    ITA  Warner Bros Italia S.P.A.      37520.80
#
#    daily_attendance date_pulled         date
# 0             66700  2023-11-17  placeholder
# 1             32469  2023-11-17  placeholder
# 2              8628  2023-11-17  placeholder
# 3              5709  2023-11-17  placeholder
# 4              5879  2023-11-17  placeholder
# 5              5323  2023-11-17  placeholder
# 6              3314  2023-11-17  placeholder
# 7              2478  2023-11-17  placeholder
# 8              2220  2023-11-17  placeholder
# 9              2025  2023-11-17  placeholder
# 11           102152  2023-11-18  placeholder
# 12            54074  2023-11-18  placeholder
# 13            15018  2023-11-18  placeholder
# 14             9105  2023-11-18  placeholder
# 15             8071  2023-11-18  placeholder
# 16             8365  2023-11-18  placeholder
# 17             7438  2023-11-18  placeholder
# 18             5769  2023-11-18  placeholder
# 19             2942  2023-11-18  placeholder
# 20             2518  2023-11-18  placeholder
# 22           181856  2023-11-19  placeholder
# 23            97669  2023-11-19  placeholder
# 24            33430  2023-11-19  placeholder
# 25            28338  2023-11-19  placeholder
# 26            20906  2023-11-19  placeholder
# 27            18435  2023-11-19  placeholder
# 28            19030  2023-11-19  placeholder
# 29            15427  2023-11-19  placeholder
# 30             6384  2023-11-19  placeholder
# 31             4950  2023-11-19  placeholder
# 33           211764  2023-11-20  placeholder
# 34            78293  2023-11-20  placeholder
# 35            36489  2023-11-20  placeholder
# 36            27928  2023-11-20  placeholder
# 37            18979  2023-11-20  placeholder
# 38            17953  2023-11-20  placeholder
# 39            12154  2023-11-20  placeholder
# 40             9859  2023-11-20  placeholder
# 41             6239  2023-11-20  placeholder
# 42             5383  2023-11-20  placeholder
